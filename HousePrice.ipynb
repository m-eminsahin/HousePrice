# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn
# %matplotlib inline

# %%
dataFrame = pd.read_csv("HousePrice.csv")

# %%
dataFrame.head()
# Out:
#      Id      SalePrice
# 0  1461  169277.052498
# 1  1462  187758.393989
# 2  1463  183583.683570
# 3  1464  179317.477511
# 4  1465  150730.079977

# %%
dataFrame.describe()
# Out:
#                 Id      SalePrice
# count  1459.000000    1459.000000
# mean   2190.000000  179183.918243
# std     421.321334   16518.303051
# min    1461.000000  135751.318893
# 25%    1825.500000  168703.011202
# 50%    2190.000000  179208.665698
# 75%    2554.500000  186789.409363
# max    2919.000000  281643.976117

# %%
dataFrame.isnull().sum()
# Out:
# Id           0
# SalePrice    0
# dtype: int64

# %%
plt.figure(figsize=(10,10))
sbn.histplot(dataFrame["SalePrice"])
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Count'>

# %%
plt.figure(figsize=(10,10))
sbn.countplot(dataFrame["Id"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Id', ylabel='count'>

# %%
dataFrame.corr()
# Out:
#                  Id  SalePrice
# Id         1.000000   0.126165
# SalePrice  0.126165   1.000000

# %%
dataFrame.corr()["SalePrice"].sort_values()
# Out:
# Id           0.126165
# SalePrice    1.000000
# Name: SalePrice, dtype: float64

# %%
sbn.scatterplot(x="Id",y="SalePrice",data=dataFrame)
# Out:
# <AxesSubplot:xlabel='Id', ylabel='SalePrice'>

# %%
dataFrame.sort_values("SalePrice",ascending = False).head(20)
# Out:
#         Id      SalePrice
# 728   2189  281643.976117
# 790   2251  280618.132617
# 803   2264  277936.126944
# 1336  2797  259423.859148
# 487   1948  255629.490470
# 804   2265  249768.279823
# 1440  2901  245283.198338
# 1362  2823  235419.373449
# 1139  2600  234707.209860
# 1293  2754  234492.248264
# 206   1667  232991.025584
# 1089  2550  230841.338626
# 1168  2629  228684.245138
# 588   2049  228617.968325
# 401   1862  228156.372839
# 1147  2608  228148.376399
# 396   1857  225810.160292
# 1352  2813  224323.710512
# 433   1894  224118.280106
# 1444  2905  223667.404552

# %%
dataFrame.sort_values("SalePrice",ascending = True).head(20)
# Out:
#         Id      SalePrice
# 1140  2601  135751.318893
# 1449  2910  137402.569856
# 138   1599  138607.971472
# 280   1741  139010.847767
# 784   2245  139169.866429
# 718   2179  139214.952188
# 124   1585  139647.095721
# 1111  2572  140196.109798
# 215   1676  140791.922472
# 565   2026  141684.196399
# 845   2306  142398.022752
# 1252  2713  142754.489166
# 1393  2854  143237.803560
# 570   2031  144959.835251
# 376   1837  145286.278144
# 11    1472  145291.245020
# 844   2305  145708.764336
# 638   2099  145997.635378
# 140   1601  146966.230340
# 662   2123  146968.379365

# %%
len(dataFrame)
# Out:
# 1459

# %%
len(dataFrame) * 0.01
# Out:
# 14.59

# %%
particularDF  = dataFrame.sort_values("SalePrice",ascending = False).iloc[14:]

# %%
particularDF.describe()
# Out:
#                 Id      SalePrice
# count  1445.000000    1445.000000
# mean   2187.905190  178514.380791
# std     421.345043   15007.829868
# min    1461.000000  135751.318893
# 25%    1823.000000  168590.782410
# 50%    2186.000000  179176.352181
# 75%    2552.000000  186453.264469
# max    2919.000000  228156.372839

# %%
plt.figure(figsize=(7,5))
sbn.histplot(particularDF["SalePrice"])
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Count'>

# %%
dataFrame.describe()
# Out:
#                 Id      SalePrice
# count  1459.000000    1459.000000
# mean   2190.000000  179183.918243
# std     421.321334   16518.303051
# min    1461.000000  135751.318893
# 25%    1825.500000  168703.011202
# 50%    2190.000000  179208.665698
# 75%    2554.500000  186789.409363
# max    2919.000000  281643.976117

# %%
dataFrame.groupby("Id").mean()["SalePrice"]
# Out:
# Id
# 1461    169277.052498
# 1462    187758.393989
# 1463    183583.683570
# 1464    179317.477511
# 1465    150730.079977
#             ...
# 2915    167081.220949
# 2916    164788.778231
# 2917    219222.423400
# 2918    184924.279659
# 2919    187741.866657
# Name: SalePrice, Length: 1459, dtype: float64

# %%
particularDF.groupby("Id").mean()["SalePrice"]
# Out:
# Id
# 1461    169277.052498
# 1462    187758.393989
# 1463    183583.683570
# 1464    179317.477511
# 1465    150730.079977
#             ...
# 2915    167081.220949
# 2916    164788.778231
# 2917    219222.423400
# 2918    184924.279659
# 2919    187741.866657
# Name: SalePrice, Length: 1445, dtype: float64

# %%
dataFrame[dataFrame.Id != 1465].groupby("Id").mean()["SalePrice"]
# Out:
# Id
# 1461    169277.052498
# 1462    187758.393989
# 1463    183583.683570
# 1464    179317.477511
# 1466    177150.989247
#             ...
# 2915    167081.220949
# 2916    164788.778231
# 2917    219222.423400
# 2918    184924.279659
# 2919    187741.866657
# Name: SalePrice, Length: 1458, dtype: float64

# %%
dataFrame = particularDF

# %%
dataFrame.describe()
# Out:
#                 Id      SalePrice
# count  1445.000000    1445.000000
# mean   2187.905190  178514.380791
# std     421.345043   15007.829868
# min    1461.000000  135751.318893
# 25%    1823.000000  168590.782410
# 50%    2186.000000  179176.352181
# 75%    2552.000000  186453.264469
# max    2919.000000  228156.372839

# %%
dataFrame = dataFrame[dataFrame.Id != 1465]

# %%
dataFrame.groupby("Id").mean()["SalePrice"]
# Out:
# Id
# 1461    169277.052498
# 1462    187758.393989
# 1463    183583.683570
# 1464    179317.477511
# 1466    177150.989247
#             ...
# 2915    167081.220949
# 2916    164788.778231
# 2917    219222.423400
# 2918    184924.279659
# 2919    187741.866657
# Name: SalePrice, Length: 1444, dtype: float64

# %%
dataFrame.head()
# Out:
#         Id      SalePrice
# 401   1862  228156.372839
# 1147  2608  228148.376399
# 396   1857  225810.160292
# 1352  2813  224323.710512
# 433   1894  224118.280106

# %%
y = dataFrame["SalePrice"].values
x = dataFrame.drop("SalePrice",axis=1).values

# %%
y
# Out:
# array([228156.37283916, 228148.37639912, 225810.16029218, ...,
#        138607.9714725 , 137402.56985559, 135751.31889282])

# %%
x
# Out:
# array([[1862],
#        [2608],
#        [1857],
#        ...,
#        [1599],
#        [2910],
#        [2601]], dtype=int64)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3,random_state=15)

# %%
len(x_train)
# Out:
# 1010

# %%
len(x_test)
# Out:
# 434

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_test = scaler.transform(x_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
x_train.shape
# Out:
# (1010, 1)

# %%
model = Sequential()

model.add(Dense(10, activation="relu"))
model.add(Dense(10, activation="relu"))
model.add(Dense(10, activation="relu"))
model.add(Dense(10, activation="relu"))
model.add(Dense(10, activation="relu"))
model.add(Dense(10, activation="relu"))

model.add(Dense(1))

model.compile(optimizer = "adam", loss = "mse")

# %%
model.fit(x=x_train, y=y_train, validation_data=(x_test,y_test),batch_size=150,epochs=200)
# Out:
# Epoch 1/200
# 7/7 [==============================] - 1s 24ms/step - loss: 32114821120.0000 - val_loss: 32062003200.0000
# Epoch 2/200
# 7/7 [==============================] - 0s 7ms/step - loss: 32114800640.0000 - val_loss: 32061984768.0000
# Epoch 3/200
# 7/7 [==============================] - 0s 6ms/step - loss: 32114780160.0000 - val_loss: 32061960192.0000
# Epoch 4/200
# 7/7 [==============================] - 0s 7ms/step - loss: 32114759680.0000 - val_loss: 32061941760.0000
# Epoch 5/200
# 7/7 [==============================] - 0s 7ms/step - loss: 32114728960.0000 - val_loss: 32061906944.0000
# Epoch 6/200
# 7/7 [==============================] - 0s 6ms/step - loss: 32114698240.0000 - val_loss: 32061870080.0000
# Epoch 7/200
# 7/7 [==============================] - 0s 7ms/step - loss: 32114655232.0000 - val_loss: 32061825024.0000
# Epoch 8/200
# 7/7 [==============================] - 0s 7ms/step - loss: 32114610176.0000 - val_loss: 32061771776.0000
# Epoch 9/200
# ...

# %%
lostData = pd.DataFrame(model.history.history)

# %%
lostData
# Out:
#              loss      val_loss
# 0    3.211482e+10  3.206200e+10
# 1    3.211480e+10  3.206198e+10
# 2    3.211478e+10  3.206196e+10
# 3    3.211476e+10  3.206194e+10
# 4    3.211473e+10  3.206191e+10
# ..            ...           ...
# 195  8.604465e+08  9.833237e+08
# 196  8.558166e+08  9.779860e+08
# 197  8.512335e+08  9.726499e+08
# 198  8.466689e+08  9.673181e+08
# 199  8.419470e+08  9.621154e+08
#
# [200 rows x 2 columns]

# %%
lostData.plot()
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
guessSeries = model.predict(x_test)
# Out:
# 14/14 [==============================] - 0s 2ms/step

# %%
guessSeries
# Out:
# array([[134860.52 ],
#        [189979.92 ],
#        [218308.77 ],
#        [181007.03 ],
#        [142423.4  ],
#        [151844.98 ],
#        [133963.22 ],
#        [157228.72 ],
#        [134604.17 ],
#        [205169.81 ],
#        [203503.44 ],
#        [206003.02 ],
#        [129476.78 ],
#        [172290.44 ],
#        [153960.02 ],
#        [182160.67 ],
#        [162035.66 ],
#        [156267.36 ],
#        [141910.67 ],
#        [191005.4  ],
#        [128387.21 ],
#        [199081.05 ],
#        [214847.75 ],
#        [130886.79 ],
#        [147486.7  ],
#        [190428.58 ],
#        [164855.72 ],
#        [208246.23 ],
#        [136462.83 ],
#        [154729.12 ],
#        [142167.03 ],
#        [192992.28 ],
#        [141397.94 ],
#        [143577.06 ],
#        [175559.16 ],
#        [158766.94 ],
#        [200555.17 ],
#        [198888.8  ],
#        [148576.28 ],
#        [155241.88 ],
#        [150563.12 ],
#        [144987.11 ],
#        [143192.52 ],
# ...

# %%
mean_absolute_error(y_test,guessSeries)
# Out:
# 25777.221401069368

# %%
dataFrame.describe()
# Out:
#                 Id      SalePrice
# count  1444.000000    1444.000000
# mean   2188.405817  178533.621997
# std     421.060884   14995.189259
# min    1461.000000  135751.318893
# 25%    1823.750000  168603.443820
# 50%    2186.500000  179178.410713
# 75%    2552.250000  186474.259902
# max    2919.000000  228156.372839

# %%
plt.scatter(y_test,guessSeries)
plt.plot(y_test,y_test,"r+-")

# %%
dataFrame.iloc[2]
# Out:
# Id             1857.000000
# SalePrice    225810.160292
# Name: 396, dtype: float64

# %%
HousePrice = dataFrame.drop("SalePrice",axis=1).iloc[2]

# %%
HousePrice = scaler.transform(HousePrice.values.reshape(1,-1))

# %%
model.predict(HousePrice)
# Out:
# 1/1 [==============================] - 0s 29ms/step
# array([[152998.62]], dtype=float32)
